# %% [markdown]
# # COGS 118A- Final Project

# %% [markdown]
# # Names
#
#
# - Yiyang Cao
# - Pu Tan
# - Zixu Wang
# - Zefang Yuan

# %% [markdown]
# # Abstract
# The project focused on predicting whether the client will subscribe to a term deposit term or not, helping with constructing a better bank marketing decision support system.
#
# The data is related to a bank marketing campaign from a Portuguese banking institution, with the raw data collecting by direct phone calls. The clients were asked several questions potentially related to future subscription (yes or no) of the product (i.e. the bank term deposit), and more than one contact with the same client was required. More related dataset information will be described in the Data part below. To answer the classification question, we would divide the whole dataset into two subsets, i.e., the training set and the test set, with a split ratio of 80%:20%.  Then implementation with candidate models, such as decision tree, k-NN, and linear SVM, would be performed. These models are firstly trained with the training set and then evaluated with the test set.
#
# The potential evaluation metrices used are Root Mean Squared Error (RMSE) and Mean Absolute Error (MAE). We would choose the best-performed model under these evaluation metrices.

# %% [markdown]
# # Background
#
# Marketing selling campaigns constitute a typical strategy to enhance business. Companies use direct marketing when targeting segments of customers by contacting them to meet a specific goal.<a name="cite1"></a>[<sup>[1]</sup>](#cite1) We want to categorize the potential customers who will subscribe to the bank term deposit from customers' information such as age, job ,housing, education and loan. The data we used is related to the direct marketing campaigns of a Portuguese banking institution. Sergio Moro, Paulo Cortez, Paulo Rita have done previous research on the topic of predicting the success of bank telemarketing.<a name="cite2"></a>[<sup>[2]</sup>](#cite2) They used a data mining approach to predict the success of telemarketing calls for selling bank long-term deposits. Besides the data mining approach, they also used logistic regression, decision trees, and neural network models to predict the success of telemarketing calls for selling bank long-term deposits. They found that the neural network presented the best results, and there are key attributes which highly relate to results.

# %% [markdown]
# # Problem Statement
#
# The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a term deposit. We are going to predict if the client will subscribe (yes/no) a term deposit. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed.
#
# The main problem here is to use the information of the clients, campaign and social and economic context attributes to predict when there are new clients with some similar but different information, whether they would subscribe the term deposit. There are different important aspects of the problem. For example, there are many client information attributes and many of them are categorical. Then we need to select the most important features and apply feature engineering to transform these attributes.
#
# This problem is worth addressing because if we know how well or bad the client would like to subscribe the term deposite, the bank would know how much revenue would they obtain from the business. If the revenue is high, then they should keep doing campaigns to attract their clients. It not, then they may need to changethe strategy or figure out other ways to promote their services.
#
# Based on the context of data, we are going to solve the problem by classification. The outcome 'no' is denoted as class 0, and 'yes' is demoted as class 1. The potential solution is by using decision trees, KNN, etc. to classify. The performance of the problem can be measured by metrics such as accuracy and Precision-Recall Metrics.
#
# At the end, we will find the best performed model by comparing the metrics of different models we used. More detials will be provide in Proposed Solution section.

# %% [markdown]
# # Data
#
# https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
#
# The datasets were from the University of California Irvine Machine Learning Repository. The data is related to direct marketing campaigns of a Portuguese banking institution.
#
# We plan to mainly use bank-full.csv dataset. The dataset contains 45307 observations and 20 variables ordered by date. Specifically, there are 10 numerical variables and 10 categorical variables as shown below. One observation comes with 10 numerical variables and 10 categorical variables.
#
# Numeric: age, job, duration, campaign(number of contacts performed during campaign),pdays(number of days that passed by after the client was last contacted from a previous campaign), previous (number of contacts performed before this campaign and for this client), emp.var.rate (employment variation rate - quarterly indicator), cons.price.idx (consumer price index), cons.conf.idx(consumer confidence index - monthly indicator ),euribor3m (euribor 3 month rate), nr.employed (number of employees).
#
# We would remove some social and economic context attributes, such as employment variation rate and consumer price index.
#
# Categorical: job, marital, education, default, housing, loan, contact, month, day of week, poutcome(outcome of the previous marketing campaign).
#
# Finally, we have 16 variables, specifically, with 9 categorical variables and 7 numeric variables. More selections and data transformation might be needed as going.
# Numeric: age, balance, month, duration, campaign, pdays, previous
# Catrgorical: job, marital, education, default, housing, loan, contact, day, poutcome

# %% [markdown]
# # Proposed Solution
# We are dealing with an n-dimensional dataset (n>10), and the classifier with 2 classes. we can be using a hyper-plane to make a decision boundary, a decision tree to classify or a k-NN to find the predictions.
#
# First is the decision boundary, we need find a hyper-plane. The model parameter w is along the normal direction that is orthogonal to the decision boundary. Calculate the W-dot-X and the biases to classify data.
# ![image-2.png](attachment:image-2.png)
#
# The easier way is the decision tree. Iterative Dichotomizer 3. Find the entropy to optimal the tree. Easy to overfit. Needs some kind of pruning and tree-growth limits to avoid overfitting.
# ![image-4.png](attachment:image-4.png)
#
# The last one is K-nearest neighbors. Using the Euclidean distance for every points between test points and training points. Find an optimal K value and classify the dataset. Increasing k reduces variance, and increases bias. For high-dimensional space, a problem that is the nearest neighbor may not be very close at all.
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # Evaluation Metrics
#
# Based on our data and problem statement, we can choose the following metrics to evaluate our models.
#
# * Accuracy. It would give a good sense of the overall performance of the prediction.
#
#     Accuracy = Correct Predictions / Total Predictions
#
#     In this case, accuracy could tell us how well the client would or would no subscribe the term deposit. This could give us a general idea of whether the bank should keep promoting via campaigns or not.
#
#
# * Precision-Recall Metrics. Since our dataset is imbalanced data. That is, the majority of the outcome is 'no' while the minority is 'yes'. In this sense, Precision-Recall Metrics is helpful to evaluate how well the minority class is predicted.
#
#     Precision summarizes the fraction of examples assigned the minority class that belong to the minority class.
#
#     Precision = TruePositive / (TruePositive + FalsePositive)
#
#     Recall summarizes how well the minority class is predicted.
#
#     Recall = TruePositive / (TruePositive + FalseNegative)
#
#     In this case, Precision-Recall Metrics could tell us how many the client would actually subscribe the term deposit. This could give us an clear idea of whether the bank should keep promoting via campaigns or not.

# %% [markdown]
# # Preliminary results

# %%
import numpy as np
import pandas as pd

# %%
# load data
df = pd.read_csv('bank-full.csv')
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
# Drop redundant and unnesecerry columns
df = df.drop(['contact', 'duration', 'pdays', 'poutcome'], axis=1)

# %%
# 0=NO and 1=YES
df['y'] = df['y'].replace({'yes': 1, 'no': 0})
df.head(10)
# Out:
#    age           job   marital  education default  balance housing loan  day  \
# 0   58    management   married   tertiary      no     2143     yes   no    5
# 1   44    technician    single  secondary      no       29     yes   no    5
# 2   33  entrepreneur   married  secondary      no        2     yes  yes    5
# 3   47   blue-collar   married    unknown      no     1506     yes   no    5
# 4   33       unknown    single    unknown      no        1      no   no    5
# 5   35    management   married   tertiary      no      231     yes   no    5
# 6   28    management    single   tertiary      no      447     yes  yes    5
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no    5
# 8   58       retired   married    primary      no      121     yes   no    5
# 9   43    technician    single  secondary      no      593     yes   no    5
#
#   month  campaign  previous  y
# 0   may         1         0  0
# 1   may         1         0  0
# ...

# %% [markdown]
# # EDA

# %%
# check the info for attricutes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   day        45211 non-null  int64
#  9   month      45211 non-null  object
#  10  campaign   45211 non-null  int64
#  11  previous   45211 non-null  int64
#  12  y          45211 non-null  int64
# dtypes: int64(6), object(7)
# memory usage: 4.5+ MB

# %%
#check the shape of dataframe
df.shape
# Out:
# (45211, 13)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#                 age        balance           day      campaign      previous  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419      2.763841      0.580323
# std       10.618762    3044.765829      8.322476      3.098021      2.303441
# min       18.000000   -8019.000000      1.000000      1.000000      0.000000
# 25%       33.000000      72.000000      8.000000      1.000000      0.000000
# 50%       39.000000     448.000000     16.000000      2.000000      0.000000
# 75%       48.000000    1428.000000     21.000000      3.000000      0.000000
# max       95.000000  102127.000000     31.000000     63.000000    275.000000
#
#                   y
# count  45211.000000
# mean       0.116985
# std        0.321406
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df['job'].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
df['marital'].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
df['education'].unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
df['month'].unique()
# Out:
# array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'jan', 'feb',
#        'mar', 'apr', 'sep'], dtype=object)

# %%
import numpy as np  #library for matrix-array analysis
import pandas as pd  #library for advanced data analysis
import matplotlib.pyplot as plt #library to plot graphs
import pickle #library to handle input/output
import seaborn as sns #seaborn wrapper plotting library
from sklearn import preprocessing
from sklearn.pipeline import Pipeline

# %% [markdown]
# From the information above and below, we can observe that there are 45211 data samples.
#
# There is no null value in the dataframe.
#
# Each data has 12 attributes.
#
# response value y, which is the value we want to predict, is binary.
#
# Among those 12 attributes, job, material, education, default, housing, loan, month are class variables. And among these class variables, default, housing, and loan are binary. Job, material, education, month are multiple-class variables.

# %%
# Visualizing pairplots and distribution of predictors and response
# Preprocessing categorical data

# %%
from sklearn import preprocessing
# Convert strings categorical names to integers
trans_job = preprocessing.LabelEncoder().fit_transform(df["job"])
trans_mar = preprocessing.LabelEncoder().fit_transform(df["marital"])
trans_edu = preprocessing.LabelEncoder().fit_transform(df["education"])
trans_default = preprocessing.LabelEncoder().fit_transform(df["default"])
trans_hou = preprocessing.LabelEncoder().fit_transform(df["housing"])
trans_loan = preprocessing.LabelEncoder().fit_transform(df["loan"])
trans_mon = preprocessing.LabelEncoder().fit_transform(df["month"])
cate = [trans_job,trans_mar,trans_edu,trans_default,trans_hou,trans_loan,trans_mon,df["y"]]
cate2 = pd.DataFrame(cate).T
sns.pairplot(cate2)
# 0 for job; 1 for marital; 2 for education; 3 for default; 4 for housing; 5 for loan; 6 for month; 7 for y

# %%
fig0, ax0 = plt.subplots()
ax0.set_title('job')
ax0.boxplot(trans_job)
fig1, ax1 = plt.subplots()
ax1.set_title('marital')
ax0.boxplot(trans_mar)
fig2, ax2 = plt.subplots()
ax2.set_title('education')
ax2.boxplot(trans_edu)
fig3, ax3 = plt.subplots()
ax3.set_title('default')
ax3.boxplot(trans_default)
fig4, ax4 = plt.subplots()
ax4.set_title('housing')
ax4.boxplot(trans_hou)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8294aedc40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8294af93a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8294aed8b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8294af9ac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8294af9e50>],
#  'means': []}

# %%
fig5, ax5 = plt.subplots()
ax5.set_title('loan')
ax5.boxplot(trans_loan)
fig6, ax6 = plt.subplots()
ax6.set_title('month')
ax6.boxplot(trans_mon)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f82949fd760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f82949fdd60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f82949fd3d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8294a0c4c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8294a0c850>],
#  'means': []}

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.set(style="ticks", color_codes=True)
#pairPlot = sns.pairplot(df)
sns.pairplot(df, hue='y')

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('age')
ax1.boxplot(df[['age']])
fig2, ax2 = plt.subplots()
ax2.set_title('balance')
ax2.boxplot(df[['balance']])
fig3, ax3 = plt.subplots()
ax3.set_title('day')
ax3.boxplot(df[['day']])
fig4, ax4 = plt.subplots()
ax4.set_title('campaign')
ax4.boxplot(df[['campaign']])
fig5, ax5 = plt.subplots()
ax5.set_title('previous')
ax5.boxplot(df[['previous']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8287dd97f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8287dd9f10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8287dd9460>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8287de3670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8287de3a00>],
#  'means': []}

# %% [markdown]
# From the boxplot above, we can observe that there are signigficant outliers in balance, campaign, and previous. We may consider the effect from outliers if our model doesn't perform well.

# %% [markdown]
# # Feature Engineering & Base Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import sklearn.preprocessing as pp
from sklearn import metrics
from sklearn.model_selection import learning_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import plot_confusion_matrix

# %%
# features
X = df.drop('y', axis=1)
# outcome
y = df.y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=12)

# %% [markdown]
# ## Decision Tree

# %%
# Numeric columns and associated transformers
num_feat = ['age', 'balance', 'day', 'campaign', 'previous']
num_transformer = Pipeline(steps=[
    ('scaler', pp.StandardScaler())   # z-scale
])

# Categorical columns and associated transformers
cat_feat = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'month']
cat_transformer = Pipeline(steps=[
    ('onehot', pp.OneHotEncoder())     # output from Ordinal becomes input to OneHot
])

# preprocessing pipeline (put them together)
preproc = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_feat),
        ('cat', cat_transformer, cat_feat)
    ])

pl = Pipeline(steps=[('preprocessor', preproc), ('classifier', DecisionTreeClassifier())])

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=pl, X=X_train, y=y_train, cv=5,
            train_sizes=np.linspace(0.1, 1.0, 10), n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
pl.fit(X_train, y_train)

# performance on training data
pred_train = pl.predict(X_train)
rmse_train = np.sqrt(np.mean((pred_train - y_train)**2))
# train accuracy
acc_train = pl.score(X_train, y_train)
# train f1-score
f1_train = metrics.f1_score(y_train, pred_train)

print ("train RMSE: %s" % rmse_train)
print ("train accuracy: %s" % acc_train)
print ("train f1-score: %s" % f1_train)
# Out:
# train RMSE: 0.0
# train accuracy: 1.0
# train f1-score: 1.0

# %%
# performance on test data -- what we really care about
pred_test = pl.predict(X_test)
rmse_test = np.sqrt(np.mean((pred_test - y_test)**2))
# test accuracy
acc_test = pl.score(X_test, y_test)
# test f1-score
f1_test = metrics.f1_score(y_test, pred_test)

print ("test RMSE: %s" % rmse_test)
print ("test accuracy: %s" % acc_test)
print ("test f1-score: %s" % f1_test)
# Out:
# test RMSE: 0.4259532304451843
# test accuracy: 0.8185638454733117
# test f1-score: 0.2814598540145985

# %%
plot_confusion_matrix(pl, X_test, y_test)
plt.grid(False)

# %%
# the importance of each attribute
dict(zip(X.columns, pl.named_steps['classifier'].feature_importances_))
# Out:
# {'age': 0.16339470526557856,
#  'job': 0.24071000722696836,
#  'marital': 0.1228652089903258,
#  'education': 0.0642395637059512,
#  'default': 0.048634417586597874,
#  'balance': 0.01143852868853243,
#  'housing': 0.012782061484735052,
#  'loan': 0.006526940029089912,
#  'day': 0.004758500078182706,
#  'month': 0.013127458835120604,
#  'campaign': 0.006356781934191428,
#  'previous': 0.005120319146554026}

# %% [markdown]
# ### Model Selection for Decision Tree (hyper-parameters)

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    'classifier__max_depth': [8,10,12,15], 
    'classifier__min_samples_split':[15,18,20,22,25],
    'classifier__min_samples_leaf':[15,17,20,22,25]
}
clf = GridSearchCV(pl, parameters, cv = 5)
clf.fit(X_train, y_train)
clf.best_params_

# test accuracy for the best model
clf_best = clf.best_estimator_
clf_best.score(X_test, y_test)
# Out:
# 0.8851371276909467

# %% [markdown]
# Compared to the model above, we see the improvement of the accuracy after model selection.

# %% [markdown]
# ## Random Forest

# %%
# Numeric columns and associated transformers
num_feat = ['age', 'balance', 'day', 'campaign', 'previous']
num_transformer = Pipeline(steps=[
    ('scaler', pp.StandardScaler())   # z-scale
])

# Categorical columns and associated transformers
cat_feat = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'month']
cat_transformer = Pipeline(steps=[
    ('onehot', pp.OneHotEncoder())     # output from Ordinal becomes input to OneHot
])

# preprocessing pipeline (put them together)
preproc = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_feat),
        ('cat', cat_transformer, cat_feat)
    ])

pl2 = Pipeline(steps=[('preprocessor', preproc), ('classifier', RandomForestClassifier())])

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=pl2, X=X_train, y=y_train, cv=5,
                                train_sizes=np.linspace(0.1, 1.0, 10), n_jobs=1)

train_mean = np.mean(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
pl2.fit(X_train, y_train)

# performance on training data
pred_train = pl2.predict(X_train)
rmse_train = np.sqrt(np.mean((pred_train - y_train)**2))
# train accuracy
acc_train = pl2.score(X_train, y_train)
# train f1-score
f1_train = metrics.f1_score(y_train, pred_train)

print ("train RMSE: %s" % rmse_train)
print ("train accuracy: %s" % acc_train)
print ("train f1-score: %s" % f1_train)
# Out:
# train RMSE: 0.007949663105384674
# train accuracy: 0.9999368028565109
# train f1-score: 0.9997307485191169

# %%
# performance on test data -- what we really care about
pred_test = pl2.predict(X_test)
rmse_test = np.sqrt(np.mean((pred_test - y_test)**2))
# test accuracy
acc_test = pl2.score(X_test, y_test)
# test f1-score
f1_test = metrics.f1_score(y_test, pred_test)

print ("test RMSE: %s" % rmse_test)
print ("test accuracy: %s" % acc_test)
print ("test f1-score: %s" % f1_test)
# Out:
# test RMSE: 0.3332104364028083
# test accuracy: 0.8889708050722501
# test f1-score: 0.2689320388349514

# %%
plot_confusion_matrix(pl2, X_test, y_test)
plt.grid(False)

# %% [markdown]
# ## KNN

# %%
# Numeric columns and associated transformers
num_feat = ['age', 'balance', 'day', 'campaign', 'previous']
num_transformer = Pipeline(steps=[
    ('scaler', pp.StandardScaler())   # z-scale
])

# Categorical columns and associated transformers
cat_feat = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'month']
cat_transformer = Pipeline(steps=[
    ('onehot', pp.OneHotEncoder())     # output from Ordinal becomes input to OneHot
])

# preprocessing pipeline (put them together)
preproc = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_feat),
        ('cat', cat_transformer, cat_feat)
    ])

pl3 = Pipeline(steps=[('preprocessor', preproc), ('classifier', KNeighborsClassifier(n_neighbors=9))])

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=pl3, X=X_train, y=y_train, cv=5,
                                        train_sizes=np.linspace(0.1, 1.0, 10), n_jobs=1)

train_mean = np.mean(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
pl3.fit(X_train, y_train)

# performance on training data
pred_train = pl3.predict(X_train)
rmse_train = np.sqrt(np.mean((pred_train - y_train)**2))
# train accuracy
acc_train = pl3.score(X_train, y_train)
# train f1-score
f1_train = metrics.f1_score(y_train, pred_train)

print ("train RMSE: %s" % rmse_train)
print ("train accuracy: %s" % acc_train)
print ("train f1-score: %s" % f1_train)
# Out:
# train RMSE: 0.32772480125823517
# train accuracy: 0.8925964546402503
# train f1-score: 0.24817518248175183

# %%
# performance on test data -- what we really care about
pred_test = pl3.predict(X_test)
rmse_test = np.sqrt(np.mean((pred_test - y_test)**2))
# test accuracy
acc_test = pl3.score(X_test, y_test)
# test f1-score
f1_test = metrics.f1_score(y_test, pred_test)

print ("test RMSE: %s" % rmse_test)
print ("test accuracy: %s" % acc_test)
print ("test f1-score: %s" % f1_test)
# Out:
# test RMSE: 0.33891425509862133
# test accuracy: 0.8851371276909467
# test f1-score: 0.1791359325605901

# %%
plot_confusion_matrix(pl3, X_test, y_test)
plt.grid(False)

# %% [markdown]
# # Results
#
# Our project focus on predicting the potential costumer’s decision making in purchasing the bank product or not, and constructed a supervised binary classification problem. Random forest shows the best performance in predicting the clients’ behavior with an accuracy of 0.889. Under the setting of binary classification, we selected proper algorithms among Logistic regression, decision trees, support vector machine, and not algorithms for regression without transformation, and used root mean square deviation as a metric to evaluate model performances. The original dataset contained over 5000 data points about basic clients’ information, such as job, age, and loan. With enough data, we prefer algorithms such as random forest and not leave-one-out cross-validation. With the categorical attributes, such as job, and education, we utilize one-hot encoding to convert those categorical variables into a form to perform prediction. The job and age have higher feature importance and could influence clients'decision-making the most.
#
#
# Random forest and decision tree have similar performance. The random forest has slightly higher accuracy and the decision tree has a better f1-score and lower RMSE.KNN performs the worst. In other words, the random forest algorithm might predict the clients’ decision with poor precision and recall, indicating underfitting on an unbalanced dataset. The reason might be that most of the clients are not purchasing the product in the training set and thus gave an uneven distribution of observations.For the poor performance of KNN, it may caused by the low number of k-nearest neighbor. Since our dataset contains huge amount of data, the computational cost of large number of k-nearest neighbor will be huge. Based on the learning curve, the curve is flat and did not have significant change along with increasing training data size, indicating a big enough dataset and an unbalanced dataset as well. The learning curve of KNN is very special, since it presents a concave shape.However, there is no significant increase in trainning accuracy of validation accuracy. From this observation, our data is sufficient.

# %% [markdown]
# # Discussion
#
# ### Interpreting the result
#
# Our three models performs very bad in the task that predicts the potential customers who are willing to buy the product, since the false negative rate is very high. Imagine the situation, using the result generated by random forest, that our model predicts 486 customers who are willing to buy the product. After calling these customers, we find that 0nly 56% of these people will buy the product, and in the same time, we loss 1297 potential customers. In this situation, the loss of potential customers is intolerable. These issue is caused by the heavily unbalanced data.
#
# ### Limitations
#
# From the performance of the modeling, we can see that for all machine learning algorithms we did, the accuracy of the prediction is prettry high (> 80%), but the f1 score which can also see as recall and precision score is relatively low. The reason for that is because the data is imbalanced. There are much greater proportion of no class than the yes class. That is, the majority of the client did not subscribe a term deposit. In this sense, the model is more likely to overfit the data to no class.
#
# In order to solve this problem, we might need to implement the method to handle imbalanced data such as resampling techniques.
#
# Besides,it would be good to explore more hyperparams. We explored 3 hyperparams (max_depth, min_samples_leaf, min_samples_split) for the Decision Tree model. There are many other hyperparams we have not explored yet. It would be more convincing if we could explore more of them to see which hyperparams play the most important role in this case.
#
# For the random forest, the limitations are the same above.
#
# For KNN, since our dataset is very huge, the large K neighbor will create a huge computational cost. This limitation may contribute to its poor performance.
#
# ### Ethics & Privacy
#
# There might be a lot of ethical concerns during the process of the project. It could be raised during data collection, data storage, analysis, modeling, and deployment.
#
# For example, during the data collection process, there might be personal information such as name, social security number, etc. be collected. In this case, as people who are going to use the data to do analysis, it is important to remove these private information before analysis.
#
# There also might be dataset bias problem during the analysis. In this case, since the data were collected in bias, the result after using these data is also bias. To address this issue, it is necessary to confirm the data before using it, or take extra action to process data to address the biasness.
#
#
# ### Conclusion
#
# Our models trained by the given unbalanced dataset have poor performance in the task that predicts who will subscribe the product. This is because of the high false negative rate, which means if we use the result from these models, we will loss lots of potential customers who will subscribe the product.

# %% [markdown]
# # Footnotes
#
# <a name="cite1"></a>1.[^](#cite1): S´ergio Moro, Paulo Cortez, Paulo Rita (19 February 2014) A Data-Driven Approach to Predict the Success of Bank Telemarketing. https://core.ac.uk/download/pdf/55631291.pdf<br>
# <a name="cite2"></a>2.[^](#cite2): S´ergio Moro, Paulo Cortez, Paulo Rita (19 February 2014) A Data-Driven Approach to Predict the Success of Bank Telemarketing. https://www.sciencedirect.com/science/article/abs/pii/S016792361400061X<br>
